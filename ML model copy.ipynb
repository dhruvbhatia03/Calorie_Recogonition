# %%
import numpy as np
import pandas as pd


import os
for dirname, _, filenames in os.walk('D:/MPR Project/dataset/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# D:/MPR Project/dataset/test\apple\Image_1.jpg
# D:/MPR Project/dataset/test\apple\Image_10.jpg
# D:/MPR Project/dataset/test\apple\Image_2.jpg
# D:/MPR Project/dataset/test\apple\Image_3.jpg
# D:/MPR Project/dataset/test\apple\Image_4.jpg
# D:/MPR Project/dataset/test\apple\Image_5.jpg
# D:/MPR Project/dataset/test\apple\Image_6.JPG
# D:/MPR Project/dataset/test\apple\Image_7.jpg
# D:/MPR Project/dataset/test\apple\Image_8.jpg
# D:/MPR Project/dataset/test\apple\Image_9.jpg
# D:/MPR Project/dataset/test\banana\Image_1.jpg
# D:/MPR Project/dataset/test\banana\Image_10.jpg
# D:/MPR Project/dataset/test\banana\Image_2.jpg
# D:/MPR Project/dataset/test\banana\Image_3.jpg
# D:/MPR Project/dataset/test\banana\Image_4.jpg
# D:/MPR Project/dataset/test\banana\Image_5.jpg
# D:/MPR Project/dataset/test\banana\Image_6.jpg
# D:/MPR Project/dataset/test\banana\Image_8.jpg
# D:/MPR Project/dataset/test\banana\Image_9.jpg
# D:/MPR Project/dataset/test\beetroot\Image_1.jpg
# D:/MPR Project/dataset/test\beetroot\Image_10.jpg
# D:/MPR Project/dataset/test\beetroot\Image_2.jpg
# D:/MPR Project/dataset/test\beetroot\Image_3.jpg
# D:/MPR Project/dataset/test\beetroot\Image_4.jpg
# D:/MPR Project/dataset/test\beetroot\Image_5.jpg
# D:/MPR Project/dataset/test\beetroot\Image_6.jpg
# D:/MPR Project/dataset/test\beetroot\Image_7.jpg
# D:/MPR Project/dataset/test\beetroot\Image_8.jpg
# D:/MPR Project/dataset/test\beetroot\Image_9.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_1.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_10.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_2.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_3.jpeg
# D:/MPR Project/dataset/test\bell pepper\Image_4.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_5.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_6.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_7.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_8.jpg
# D:/MPR Project/dataset/test\bell pepper\Image_9.jpg
# D:/MPR Project/dataset/test\cabbage\Image_1.jpg
# D:/MPR Project/dataset/test\cabbage\Image_10.jpg
# D:/MPR Project/dataset/test\cabbage\Image_2.jpg
# D:/MPR Project/dataset/test\cabbage\Image_3.jpg
# D:/MPR Project/dataset/test\cabbage\Image_4.jpg
# D:/MPR Project/dataset/test\cabbage\Image_5.jpg
# D:/MPR Project/dataset/test\cabbage\Image_6.jpg
# D:/MPR Project/dataset/test\cabbage\Image_7.jpg
# D:/MPR Project/dataset/test\cabbage\Image_8.jpg
# D:/MPR Project/dataset/test\cabbage\Image_9.jpg
# D:/MPR Project/dataset/test\capsicum\Image_1.jpg
# D:/MPR Project/dataset/test\capsicum\Image_10.jpg
# D:/MPR Project/dataset/test\capsicum\Image_2.jpg
# D:/MPR Project/dataset/test\capsicum\Image_3.JPG
# D:/MPR Project/dataset/test\capsicum\Image_4.jpg
# D:/MPR Project/dataset/test\capsicum\Image_5.jpg
# D:/MPR Project/dataset/test\capsicum\Image_6.jpg
# D:/MPR Project/dataset/test\capsicum\Image_7.jpg
# D:/MPR Project/dataset/test\capsicum\Image_8.jpg
# D:/MPR Project/dataset/test\capsicum\Image_9.jpg
# D:/MPR Project/dataset/test\carrot\Image_1.jpg
# D:/MPR Project/dataset/test\carrot\Image_10.jpg
# D:/MPR Project/dataset/test\carrot\Image_2.jpg
# D:/MPR Project/dataset/test\carrot\Image_3.jpg
# D:/MPR Project/dataset/test\carrot\Image_4.png
# D:/MPR Project/dataset/test\carrot\Image_5.jpg
# D:/MPR Project/dataset/test\carrot\Image_6.jpg
# D:/MPR Project/dataset/test\carrot\Image_7.JPG
# D:/MPR Project/dataset/test\carrot\Image_8.jpg
# D:/MPR Project/dataset/test\carrot\Image_9.jpeg
# D:/MPR Project/dataset/test\cauliflower\Image_1.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_10.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_2.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_3.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_4.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_5.JPG
# D:/MPR Project/dataset/test\cauliflower\Image_6.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_7.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_8.jpg
# D:/MPR Project/dataset/test\cauliflower\Image_9.jpg
# D:/MPR Project/dataset/test\chilli pepper\Image_1.jpg
# D:/MPR Project/dataset/test\chilli pepper\Image_10.jpg
# D:/MPR Project/dataset/test\chilli pepper\Image_2.png
# D:/MPR Project/dataset/test\chilli pepper\Image_3.jpg
# D:/MPR Project/dataset/test\chilli pepper\Image_4.jpg
# D:/MPR Project/dataset/test\chilli pepper\Image_5.png
# D:/MPR Project/dataset/test\chilli pepper\Image_6.jpeg
# D:/MPR Project/dataset/test\chilli pepper\Image_7.jpg
# D:/MPR Project/dataset/test\chilli pepper\Image_8.jpg
# D:/MPR Project/dataset/test\chilli pepper\Image_9.jpg
# D:/MPR Project/dataset/test\corn\Image_1.jpg
# D:/MPR Project/dataset/test\corn\Image_10.jpg
# D:/MPR Project/dataset/test\corn\Image_2.jpg
# D:/MPR Project/dataset/test\corn\Image_3.jpg
# D:/MPR Project/dataset/test\corn\Image_4.jpg
# D:/MPR Project/dataset/test\corn\Image_5.jpg
# D:/MPR Project/dataset/test\corn\Image_6.jpg
# D:/MPR Project/dataset/test\corn\Image_7.jpg
# D:/MPR Project/dataset/test\corn\Image_8.jpg
# D:/MPR Project/dataset/test\corn\Image_9.jpg
# D:/MPR Project/dataset/test\cucumber\Image_1.jpg
# D:/MPR Project/dataset/test\cucumber\Image_10.jpg
# D:/MPR Project/dataset/test\cucumber\Image_2.jpg
# D:/MPR Project/dataset/test\cucumber\Image_3.jpg
# D:/MPR Project/dataset/test\cucumber\Image_4.jpg
# D:/MPR Project/dataset/test\cucumber\Image_5.jpg
# D:/MPR Project/dataset/test\cucumber\Image_6.jpg
# D:/MPR Project/dataset/test\cucumber\Image_7.jpg
# D:/MPR Project/dataset/test\cucumber\Image_8.jpg
# D:/MPR Project/dataset/test\cucumber\Image_9.jpg
# D:/MPR Project/dataset/test\eggplant\Image_1.jpg
# D:/MPR Project/dataset/test\eggplant\Image_10.jpg
# D:/MPR Project/dataset/test\eggplant\Image_2.jpg
# D:/MPR Project/dataset/test\eggplant\Image_3.jpg
# D:/MPR Project/dataset/test\eggplant\Image_4.jpg
# D:/MPR Project/dataset/test\eggplant\Image_5.jpg
# D:/MPR Project/dataset/test\eggplant\Image_6.jpg
# D:/MPR Project/dataset/test\eggplant\Image_7.jpg
# D:/MPR Project/dataset/test\eggplant\Image_8.jpg
# D:/MPR Project/dataset/test\eggplant\Image_9.jpg
# D:/MPR Project/dataset/test\garlic\Image_1.jpg
# D:/MPR Project/dataset/test\garlic\Image_10.jpg
# D:/MPR Project/dataset/test\garlic\Image_2.jpg
# D:/MPR Project/dataset/test\garlic\Image_3.jpg
# D:/MPR Project/dataset/test\garlic\Image_4.jpg
# D:/MPR Project/dataset/test\garlic\Image_5.jpg
# D:/MPR Project/dataset/test\garlic\Image_6.jpg
# D:/MPR Project/dataset/test\garlic\Image_7.jpg
# D:/MPR Project/dataset/test\garlic\Image_8.jpg
# D:/MPR Project/dataset/test\garlic\Image_9.jpg
# D:/MPR Project/dataset/test\ginger\Image_1.jpg
# D:/MPR Project/dataset/test\ginger\Image_10.jpg
# D:/MPR Project/dataset/test\ginger\Image_2.jpg
# D:/MPR Project/dataset/test\ginger\Image_3.jpg
# D:/MPR Project/dataset/test\ginger\Image_4.jpg
# D:/MPR Project/dataset/test\ginger\Image_5.jpg
# D:/MPR Project/dataset/test\ginger\Image_6.jpg
# D:/MPR Project/dataset/test\ginger\Image_7.jpg
# D:/MPR Project/dataset/test\ginger\Image_8.jpg
# D:/MPR Project/dataset/test\ginger\Image_9.jpg
# D:/MPR Project/dataset/test\grapes\Image_1.jpg
# D:/MPR Project/dataset/test\grapes\Image_10.jpg
# D:/MPR Project/dataset/test\grapes\Image_2.jpg
# D:/MPR Project/dataset/test\grapes\Image_3.jpg
# D:/MPR Project/dataset/test\grapes\Image_4.jpg
# D:/MPR Project/dataset/test\grapes\Image_5.jpeg
# D:/MPR Project/dataset/test\grapes\Image_6.jpg
# D:/MPR Project/dataset/test\grapes\Image_7.JPG
# D:/MPR Project/dataset/test\grapes\Image_8.jpg
# D:/MPR Project/dataset/test\grapes\Image_9.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_1.jpeg
# D:/MPR Project/dataset/test\jalepeno\Image_10.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_2.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_3.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_4.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_5.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_6.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_7.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_8.jpg
# D:/MPR Project/dataset/test\jalepeno\Image_9.jpg
# D:/MPR Project/dataset/test\kiwi\Image_1.jpg
# D:/MPR Project/dataset/test\kiwi\Image_10.jpg
# D:/MPR Project/dataset/test\kiwi\Image_2.jpg
# D:/MPR Project/dataset/test\kiwi\Image_3.jpg
# D:/MPR Project/dataset/test\kiwi\Image_4.jpg
# D:/MPR Project/dataset/test\kiwi\Image_5.jpg
# D:/MPR Project/dataset/test\kiwi\Image_6.jpg
# D:/MPR Project/dataset/test\kiwi\Image_7.jpg
# D:/MPR Project/dataset/test\kiwi\Image_8.jpg
# D:/MPR Project/dataset/test\kiwi\Image_9.jpg
# D:/MPR Project/dataset/test\lemon\Image_1.png
# D:/MPR Project/dataset/test\lemon\Image_10.jpg
# D:/MPR Project/dataset/test\lemon\Image_2.jpg
# D:/MPR Project/dataset/test\lemon\Image_3.jpg
# D:/MPR Project/dataset/test\lemon\Image_4.jpg
# D:/MPR Project/dataset/test\lemon\Image_5.jpg
# D:/MPR Project/dataset/test\lemon\Image_6.png
# D:/MPR Project/dataset/test\lemon\Image_7.jpg
# D:/MPR Project/dataset/test\lemon\Image_8.jpg
# D:/MPR Project/dataset/test\lemon\Image_9.png
# D:/MPR Project/dataset/test\lettuce\Image_1.jpg
# D:/MPR Project/dataset/test\lettuce\Image_10.jpg
# D:/MPR Project/dataset/test\lettuce\Image_2.jpg
# D:/MPR Project/dataset/test\lettuce\Image_3.jpg
# D:/MPR Project/dataset/test\lettuce\Image_4.jpg
# D:/MPR Project/dataset/test\lettuce\Image_5.jpeg
# D:/MPR Project/dataset/test\lettuce\Image_6.jpg
# D:/MPR Project/dataset/test\lettuce\Image_7.jpg
# D:/MPR Project/dataset/test\lettuce\Image_8.jpg
# D:/MPR Project/dataset/test\lettuce\Image_9.jpg
# D:/MPR Project/dataset/test\mango\Image_1.jpg
# D:/MPR Project/dataset/test\mango\Image_10.jpg
# D:/MPR Project/dataset/test\mango\Image_2.jpg
# D:/MPR Project/dataset/test\mango\Image_3.jpg
# D:/MPR Project/dataset/test\mango\Image_4.jpg
# D:/MPR Project/dataset/test\mango\Image_5.jpg
# D:/MPR Project/dataset/test\mango\Image_6.jpg
# D:/MPR Project/dataset/test\mango\Image_7.jpg
# D:/MPR Project/dataset/test\mango\Image_8.jpg
# D:/MPR Project/dataset/test\mango\Image_9.jpg
# D:/MPR Project/dataset/test\onion\Image_1.jpg
# D:/MPR Project/dataset/test\onion\Image_10.jpg
# D:/MPR Project/dataset/test\onion\Image_2.jpg
# D:/MPR Project/dataset/test\onion\Image_3.jpg
# D:/MPR Project/dataset/test\onion\Image_4.jpg
# D:/MPR Project/dataset/test\onion\Image_5.jpg
# D:/MPR Project/dataset/test\onion\Image_6.jpg
# D:/MPR Project/dataset/test\onion\Image_7.png
# D:/MPR Project/dataset/test\onion\Image_8.jpg
# D:/MPR Project/dataset/test\onion\Image_9.jpg
# D:/MPR Project/dataset/test\orange\Image_1.png
# D:/MPR Project/dataset/test\orange\Image_10.png
# D:/MPR Project/dataset/test\orange\Image_2.jpg
# D:/MPR Project/dataset/test\orange\Image_3.jpg
# D:/MPR Project/dataset/test\orange\Image_4.jpg
# D:/MPR Project/dataset/test\orange\Image_5.jpg
# D:/MPR Project/dataset/test\orange\Image_6.jpg
# D:/MPR Project/dataset/test\orange\Image_7.jpg
# D:/MPR Project/dataset/test\orange\Image_8.jpeg
# D:/MPR Project/dataset/test\orange\Image_9.jpg
# D:/MPR Project/dataset/test\paprika\Image_1.jpg
# D:/MPR Project/dataset/test\paprika\Image_10.jpg
# D:/MPR Project/dataset/test\paprika\Image_2.jpg
# D:/MPR Project/dataset/test\paprika\Image_3.jpg
# D:/MPR Project/dataset/test\paprika\Image_4.jpg
# D:/MPR Project/dataset/test\paprika\Image_5.jpg
# D:/MPR Project/dataset/test\paprika\Image_6.jpg
# D:/MPR Project/dataset/test\paprika\Image_7.jpg
# D:/MPR Project/dataset/test\paprika\Image_8.jpg
# D:/MPR Project/dataset/test\paprika\Image_9.jpg
# D:/MPR Project/dataset/test\pear\Image_1.jpg
# D:/MPR Project/dataset/test\pear\Image_10.jpg
# D:/MPR Project/dataset/test\pear\Image_2.jpg
# D:/MPR Project/dataset/test\pear\Image_3.jpg
# D:/MPR Project/dataset/test\pear\Image_4.jpg
# D:/MPR Project/dataset/test\pear\Image_5.jpg
# D:/MPR Project/dataset/test\pear\Image_6.jpg
# D:/MPR Project/dataset/test\pear\Image_7.jpg
# D:/MPR Project/dataset/test\pear\Image_8.jpg
# D:/MPR Project/dataset/test\pear\Image_9.jpg
# D:/MPR Project/dataset/test\peas\Image_1.jpg
# D:/MPR Project/dataset/test\peas\Image_10.jpg
# D:/MPR Project/dataset/test\peas\Image_2.jpg
# D:/MPR Project/dataset/test\peas\Image_3.jpg
# D:/MPR Project/dataset/test\peas\Image_4.jpg
# D:/MPR Project/dataset/test\peas\Image_5.jpg
# D:/MPR Project/dataset/test\peas\Image_6.png
# D:/MPR Project/dataset/test\peas\Image_7.jpg
# D:/MPR Project/dataset/test\peas\Image_8.jpg
# D:/MPR Project/dataset/test\peas\Image_9.jpg
# D:/MPR Project/dataset/test\pineapple\Image_1.jpg
# D:/MPR Project/dataset/test\pineapple\Image_10.jpg
# D:/MPR Project/dataset/test\pineapple\Image_2.jpg
# D:/MPR Project/dataset/test\pineapple\Image_3.jpg
# D:/MPR Project/dataset/test\pineapple\Image_4.jpg
# D:/MPR Project/dataset/test\pineapple\Image_5.jpg
# D:/MPR Project/dataset/test\pineapple\Image_6.jpg
# D:/MPR Project/dataset/test\pineapple\Image_7.jpg
# D:/MPR Project/dataset/test\pineapple\Image_8.jpg
# D:/MPR Project/dataset/test\pineapple\Image_9.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_1.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_10.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_2.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_3.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_4.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_5.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_6.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_7.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_8.jpg
# D:/MPR Project/dataset/test\pomegranate\Image_9.jpg
# D:/MPR Project/dataset/test\potato\Image_1.jpg
# D:/MPR Project/dataset/test\potato\Image_10.jpg
# D:/MPR Project/dataset/test\potato\Image_2.jpg
# D:/MPR Project/dataset/test\potato\Image_3.jpg
# D:/MPR Project/dataset/test\potato\Image_4.jpg
# D:/MPR Project/dataset/test\potato\Image_5.JPG
# D:/MPR Project/dataset/test\potato\Image_6.jpg
# D:/MPR Project/dataset/test\potato\Image_7.jpg
# D:/MPR Project/dataset/test\potato\Image_8.jpg
# D:/MPR Project/dataset/test\potato\Image_9.jpg
# D:/MPR Project/dataset/test\raddish\Image_1.jpg
# D:/MPR Project/dataset/test\raddish\Image_10.jpg
# D:/MPR Project/dataset/test\raddish\Image_2.jpg
# D:/MPR Project/dataset/test\raddish\Image_3.jpg
# D:/MPR Project/dataset/test\raddish\Image_4.jpg
# D:/MPR Project/dataset/test\raddish\Image_5.png
# D:/MPR Project/dataset/test\raddish\Image_6.jpg
# D:/MPR Project/dataset/test\raddish\Image_7.jpg
# D:/MPR Project/dataset/test\raddish\Image_8.jpg
# D:/MPR Project/dataset/test\raddish\Image_9.jpeg
# D:/MPR Project/dataset/test\soy beans\Image_1.jpg
# D:/MPR Project/dataset/test\soy beans\Image_10.jpg
# D:/MPR Project/dataset/test\soy beans\Image_2.jpg
# D:/MPR Project/dataset/test\soy beans\Image_3.jpg
# D:/MPR Project/dataset/test\soy beans\Image_4.jpg
# D:/MPR Project/dataset/test\soy beans\Image_5.jpg
# D:/MPR Project/dataset/test\soy beans\Image_6.jpg
# D:/MPR Project/dataset/test\soy beans\Image_7.jpg
# D:/MPR Project/dataset/test\soy beans\Image_8.jpg
# D:/MPR Project/dataset/test\soy beans\Image_9.jpg
# D:/MPR Project/dataset/test\spinach\Image_1.jpg
# D:/MPR Project/dataset/test\spinach\Image_10.jpg
# D:/MPR Project/dataset/test\spinach\Image_2.jpg
# D:/MPR Project/dataset/test\spinach\Image_3.jpg
# D:/MPR Project/dataset/test\spinach\Image_4.jpg
# D:/MPR Project/dataset/test\spinach\Image_5.jpg
# D:/MPR Project/dataset/test\spinach\Image_6.jpg
# D:/MPR Project/dataset/test\spinach\Image_7.jpg
# D:/MPR Project/dataset/test\spinach\Image_8.jpg
# D:/MPR Project/dataset/test\spinach\Image_9.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_1.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_10.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_2.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_3.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_4.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_5.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_6.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_7.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_8.jpg
# D:/MPR Project/dataset/test\sweetcorn\Image_9.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_1.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_10.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_2.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_3.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_4.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_5.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_6.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_7.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_8.jpg
# D:/MPR Project/dataset/test\sweetpotato\Image_9.jpg
# D:/MPR Project/dataset/test\tomato\Image_1.jpg
# D:/MPR Project/dataset/test\tomato\Image_10.jpg
# D:/MPR Project/dataset/test\tomato\Image_2.jpg
# D:/MPR Project/dataset/test\tomato\Image_3.jpg
# D:/MPR Project/dataset/test\tomato\Image_4.jpg
# D:/MPR Project/dataset/test\tomato\Image_5.jpg
# D:/MPR Project/dataset/test\tomato\Image_6.jpg
# D:/MPR Project/dataset/test\tomato\Image_7.jpg
# D:/MPR Project/dataset/test\tomato\Image_8.jpg
# D:/MPR Project/dataset/test\tomato\Image_9.jpg
# D:/MPR Project/dataset/test\turnip\Image_1.jpg
# D:/MPR Project/dataset/test\turnip\Image_10.jpg
# D:/MPR Project/dataset/test\turnip\Image_2.jpg
# D:/MPR Project/dataset/test\turnip\Image_3.jpg
# D:/MPR Project/dataset/test\turnip\Image_4.jpg
# D:/MPR Project/dataset/test\turnip\Image_5.jpg
# D:/MPR Project/dataset/test\turnip\Image_6.jpg
# D:/MPR Project/dataset/test\turnip\Image_7.jpg
# D:/MPR Project/dataset/test\turnip\Image_8.jpg
# D:/MPR Project/dataset/test\turnip\Image_9.jpg
# D:/MPR Project/dataset/test\watermelon\Image_1.jpg
# D:/MPR Project/dataset/test\watermelon\Image_10.jpg
# D:/MPR Project/dataset/test\watermelon\Image_2.jpg
# D:/MPR Project/dataset/test\watermelon\Image_3.jpg
# D:/MPR Project/dataset/test\watermelon\Image_4.jpg
# D:/MPR Project/dataset/test\watermelon\Image_5.jpg
# D:/MPR Project/dataset/test\watermelon\Image_6.jpg
# D:/MPR Project/dataset/test\watermelon\Image_7.jpg
# D:/MPR Project/dataset/test\watermelon\Image_8.jpg
# D:/MPR Project/dataset/test\watermelon\Image_9.jpg
# D:/MPR Project/dataset/train\apple\Image_1.jpg
# D:/MPR Project/dataset/train\apple\Image_10.jpg
# D:/MPR Project/dataset/train\apple\Image_16.jpg
# D:/MPR Project/dataset/train\apple\Image_17.jpg
# D:/MPR Project/dataset/train\apple\Image_18.jpg
# D:/MPR Project/dataset/train\apple\Image_19.jpg
# D:/MPR Project/dataset/train\apple\Image_2.jpg
# D:/MPR Project/dataset/train\apple\Image_20.jpg
# D:/MPR Project/dataset/train\apple\Image_21.jpg
# D:/MPR Project/dataset/train\apple\Image_23.jpg
# D:/MPR Project/dataset/train\apple\Image_24.jpg
# D:/MPR Project/dataset/train\apple\Image_25.jpg
# D:/MPR Project/dataset/train\apple\Image_26.jpg
# D:/MPR Project/dataset/train\apple\Image_27.jpg
# D:/MPR Project/dataset/train\apple\Image_28.jpg
# D:/MPR Project/dataset/train\apple\Image_3.jpg
# D:/MPR Project/dataset/train\apple\Image_31.jpg
# D:/MPR Project/dataset/train\apple\Image_32.jpg
# D:/MPR Project/dataset/train\apple\Image_33.jpg
# D:/MPR Project/dataset/train\apple\Image_34.jpg
# D:/MPR Project/dataset/train\apple\Image_35.png
# D:/MPR Project/dataset/train\apple\Image_36.jpg
# D:/MPR Project/dataset/train\apple\Image_37.jpg
# D:/MPR Project/dataset/train\apple\Image_38.jpg
# D:/MPR Project/dataset/train\apple\Image_39.jpg
# D:/MPR Project/dataset/train\apple\Image_40.jpg
# D:/MPR Project/dataset/train\apple\Image_41.jpg
# D:/MPR Project/dataset/train\apple\Image_42.jpg
# D:/MPR Project/dataset/train\apple\Image_43.jpg
# D:/MPR Project/dataset/train\apple\Image_44.jpg
# D:/MPR Project/dataset/train\apple\Image_45.jpg
# D:/MPR Project/dataset/train\apple\Image_47.jpg
# D:/MPR Project/dataset/train\apple\Image_48.jpg
# D:/MPR Project/dataset/train\apple\Image_49.jpg
# D:/MPR Project/dataset/train\apple\Image_5.JPG
# D:/MPR Project/dataset/train\apple\Image_50.jpg
# D:/MPR Project/dataset/train\apple\Image_51.jpg
# D:/MPR Project/dataset/train\apple\Image_52.jpg
# D:/MPR Project/dataset/train\apple\Image_53.png
# D:/MPR Project/dataset/train\apple\Image_54.jpg
# D:/MPR Project/dataset/train\apple\Image_55.jpg
# D:/MPR Project/dataset/train\apple\Image_56.jpg
# D:/MPR Project/dataset/train\apple\Image_57.jpg
# D:/MPR Project/dataset/train\apple\Image_58.jpg
# D:/MPR Project/dataset/train\apple\Image_59.png
# D:/MPR Project/dataset/train\apple\Image_6.jpg
# D:/MPR Project/dataset/train\apple\Image_60.jpg
# D:/MPR Project/dataset/train\apple\Image_61.jpg
# D:/MPR Project/dataset/train\apple\Image_62.jpg
# D:/MPR Project/dataset/train\apple\Image_63.jpg
# D:/MPR Project/dataset/train\apple\Image_64.jpg
# D:/MPR Project/dataset/train\apple\Image_65.png
# D:/MPR Project/dataset/train\apple\Image_67.jpg
# D:/MPR Project/dataset/train\apple\Image_68.jpg
# D:/MPR Project/dataset/train\apple\Image_69.jpg
# D:/MPR Project/dataset/train\apple\Image_7.jpg
# D:/MPR Project/dataset/train\apple\Image_71.png
# D:/MPR Project/dataset/train\apple\Image_76.png
# D:/MPR Project/dataset/train\apple\Image_78.jpg
# D:/MPR Project/dataset/train\apple\Image_80.jpg
# D:/MPR Project/dataset/train\apple\Image_81.png
# D:/MPR Project/dataset/train\apple\Image_82.jpg
# D:/MPR Project/dataset/train\apple\Image_83.png
# D:/MPR Project/dataset/train\apple\Image_86.jpg
# D:/MPR Project/dataset/train\apple\Image_87.jpg
# D:/MPR Project/dataset/train\apple\Image_9.jpg
# D:/MPR Project/dataset/train\apple\Image_90.jpg
# D:/MPR Project/dataset/train\apple\Image_92.png
# D:/MPR Project/dataset/train\banana\Image_1.jpg
# D:/MPR Project/dataset/train\banana\Image_100.jpg
# D:/MPR Project/dataset/train\banana\Image_11.png
# D:/MPR Project/dataset/train\banana\Image_13.jpg
# D:/MPR Project/dataset/train\banana\Image_14.jpg
# D:/MPR Project/dataset/train\banana\Image_15.jpg
# D:/MPR Project/dataset/train\banana\Image_16.jpg
# D:/MPR Project/dataset/train\banana\Image_21.JPG
# D:/MPR Project/dataset/train\banana\Image_23.jpg
# D:/MPR Project/dataset/train\banana\Image_24.jpg
# D:/MPR Project/dataset/train\banana\Image_25.jpg
# D:/MPR Project/dataset/train\banana\Image_27.jpg
# D:/MPR Project/dataset/train\banana\Image_28.jpg
# D:/MPR Project/dataset/train\banana\Image_3.jpg
# D:/MPR Project/dataset/train\banana\Image_31.jpg
# D:/MPR Project/dataset/train\banana\Image_32.jpg
# D:/MPR Project/dataset/train\banana\Image_37.jpg
# D:/MPR Project/dataset/train\banana\Image_4.jpg
# D:/MPR Project/dataset/train\banana\Image_40.jpg
# D:/MPR Project/dataset/train\banana\Image_41.jpg
# D:/MPR Project/dataset/train\banana\Image_42.jpg
# D:/MPR Project/dataset/train\banana\Image_43.png
# D:/MPR Project/dataset/train\banana\Image_44.jpg
# D:/MPR Project/dataset/train\banana\Image_45.jpg
# D:/MPR Project/dataset/train\banana\Image_46.jpg
# D:/MPR Project/dataset/train\banana\Image_47.jpg
# D:/MPR Project/dataset/train\banana\Image_48.png
# D:/MPR Project/dataset/train\banana\Image_49.jpg
# D:/MPR Project/dataset/train\banana\Image_5.jpg
# D:/MPR Project/dataset/train\banana\Image_50.jpg
# D:/MPR Project/dataset/train\banana\Image_51.jpeg
# D:/MPR Project/dataset/train\banana\Image_52.jpg
# D:/MPR Project/dataset/train\banana\Image_53.png
# D:/MPR Project/dataset/train\banana\Image_54.jpg
# D:/MPR Project/dataset/train\banana\Image_55.jpg
# D:/MPR Project/dataset/train\banana\Image_56.jpg
# D:/MPR Project/dataset/train\banana\Image_57.jpg
# D:/MPR Project/dataset/train\banana\Image_58.png
# D:/MPR Project/dataset/train\banana\Image_59.jpg
# D:/MPR Project/dataset/train\banana\Image_6.jpg
# D:/MPR Project/dataset/train\banana\Image_61.png
# D:/MPR Project/dataset/train\banana\Image_62.jpg
# D:/MPR Project/dataset/train\banana\Image_63.jpg
# D:/MPR Project/dataset/train\banana\Image_64.jpg
# D:/MPR Project/dataset/train\banana\Image_65.png
# D:/MPR Project/dataset/train\banana\Image_66.jpg
# D:/MPR Project/dataset/train\banana\Image_67.jpg
# D:/MPR Project/dataset/train\banana\Image_68.jpg
# D:/MPR Project/dataset/train\banana\Image_69.jpg
# D:/MPR Project/dataset/train\banana\Image_71.jpg
# D:/MPR Project/dataset/train\banana\Image_72.jpg
# D:/MPR Project/dataset/train\banana\Image_73.jpg
# D:/MPR Project/dataset/train\banana\Image_75.jpg
# D:/MPR Project/dataset/train\banana\Image_76.jpg
# D:/MPR Project/dataset/train\banana\Image_77.jpg
# D:/MPR Project/dataset/train\banana\Image_79.jpg
# D:/MPR Project/dataset/train\banana\Image_8.jpg
# D:/MPR Project/dataset/train\banana\Image_80.png
# D:/MPR Project/dataset/train\banana\Image_81.jpeg
# D:/MPR Project/dataset/train\banana\Image_82.jpg
# D:/MPR Project/dataset/train\banana\Image_83.png
# D:/MPR Project/dataset/train\banana\Image_84.jpg
# D:/MPR Project/dataset/train\banana\Image_85.jpg
# D:/MPR Project/dataset/train\banana\Image_86.jpg
# D:/MPR Project/dataset/train\banana\Image_88.png
# D:/MPR Project/dataset/train\banana\Image_89.jpg
# D:/MPR Project/dataset/train\banana\Image_9.jpg
# D:/MPR Project/dataset/train\banana\Image_90.jpg
# D:/MPR Project/dataset/train\banana\Image_91.jpg
# D:/MPR Project/dataset/train\banana\Image_92.jpg
# D:/MPR Project/dataset/train\banana\Image_93.jpg
# D:/MPR Project/dataset/train\banana\Image_95.jpg
# D:/MPR Project/dataset/train\banana\Image_96.jpg
# D:/MPR Project/dataset/train\banana\Image_97.jpg
# D:/MPR Project/dataset/train\banana\Image_98.jpg
# D:/MPR Project/dataset/train\beetroot\Image_1.jpg
# D:/MPR Project/dataset/train\beetroot\Image_10.jpg
# D:/MPR Project/dataset/train\beetroot\Image_100.jpg
# D:/MPR Project/dataset/train\beetroot\Image_11.jpg
# D:/MPR Project/dataset/train\beetroot\Image_12.jpg
# D:/MPR Project/dataset/train\beetroot\Image_13.jpg
# D:/MPR Project/dataset/train\beetroot\Image_14.jpg
# D:/MPR Project/dataset/train\beetroot\Image_15.jpg
# D:/MPR Project/dataset/train\beetroot\Image_16.jpg
# D:/MPR Project/dataset/train\beetroot\Image_17.jpg
# D:/MPR Project/dataset/train\beetroot\Image_18.jpg
# D:/MPR Project/dataset/train\beetroot\Image_19.jpg
# D:/MPR Project/dataset/train\beetroot\Image_2.jpg
# D:/MPR Project/dataset/train\beetroot\Image_20.jpg
# D:/MPR Project/dataset/train\beetroot\Image_21.JPG
# D:/MPR Project/dataset/train\beetroot\Image_22.jpg
# D:/MPR Project/dataset/train\beetroot\Image_23.jpg
# D:/MPR Project/dataset/train\beetroot\Image_24.jpg
# D:/MPR Project/dataset/train\beetroot\Image_25.jpg
# D:/MPR Project/dataset/train\beetroot\Image_26.jpg
# D:/MPR Project/dataset/train\beetroot\Image_27.jpg
# D:/MPR Project/dataset/train\beetroot\Image_28.jpg
# D:/MPR Project/dataset/train\beetroot\Image_29.jpg
# D:/MPR Project/dataset/train\beetroot\Image_3.jpg
# D:/MPR Project/dataset/train\beetroot\Image_30.jpg
# D:/MPR Project/dataset/train\beetroot\Image_31.jpg
# D:/MPR Project/dataset/train\beetroot\Image_32.jpg
# D:/MPR Project/dataset/train\beetroot\Image_33.jpg
# D:/MPR Project/dataset/train\beetroot\Image_34.jpg
# D:/MPR Project/dataset/train\beetroot\Image_35.jpg
# D:/MPR Project/dataset/train\beetroot\Image_36.jpg
# D:/MPR Project/dataset/train\beetroot\Image_37.jpg
# D:/MPR Project/dataset/train\beetroot\Image_38.jpg
# D:/MPR Project/dataset/train\beetroot\Image_39.jpg
# D:/MPR Project/dataset/train\beetroot\Image_4.jpg
# D:/MPR Project/dataset/train\beetroot\Image_40.jpg
# D:/MPR Project/dataset/train\beetroot\Image_41.jpg
# D:/MPR Project/dataset/train\beetroot\Image_42.jpg
# D:/MPR Project/dataset/train\beetroot\Image_43.jpg
# D:/MPR Project/dataset/train\beetroot\Image_44.jpg
# D:/MPR Project/dataset/train\beetroot\Image_45.jpg
# D:/MPR Project/dataset/train\beetroot\Image_46.jpg
# D:/MPR Project/dataset/train\beetroot\Image_47.jpg
# D:/MPR Project/dataset/train\beetroot\Image_48.jpg
# D:/MPR Project/dataset/train\beetroot\Image_49.jpg
# D:/MPR Project/dataset/train\beetroot\Image_5.jpg
# D:/MPR Project/dataset/train\beetroot\Image_50.jpg
# D:/MPR Project/dataset/train\beetroot\Image_51.jpg
# D:/MPR Project/dataset/train\beetroot\Image_52.jpg
# D:/MPR Project/dataset/train\beetroot\Image_53.jpg
# D:/MPR Project/dataset/train\beetroot\Image_54.png
# D:/MPR Project/dataset/train\beetroot\Image_55.jpg
# D:/MPR Project/dataset/train\beetroot\Image_56.jpg
# D:/MPR Project/dataset/train\beetroot\Image_58.jpg
# D:/MPR Project/dataset/train\beetroot\Image_6.jpg
# D:/MPR Project/dataset/train\beetroot\Image_61.jpg
# D:/MPR Project/dataset/train\beetroot\Image_62.jpg
# D:/MPR Project/dataset/train\beetroot\Image_63.jpg
# D:/MPR Project/dataset/train\beetroot\Image_64.jpg
# D:/MPR Project/dataset/train\beetroot\Image_65.jpg
# D:/MPR Project/dataset/train\beetroot\Image_66.jpg
# D:/MPR Project/dataset/train\beetroot\Image_68.jpg
# D:/MPR Project/dataset/train\beetroot\Image_69.jpg
# D:/MPR Project/dataset/train\beetroot\Image_7.jpg
# D:/MPR Project/dataset/train\beetroot\Image_72.jpg
# D:/MPR Project/dataset/train\beetroot\Image_75.jpg
# D:/MPR Project/dataset/train\beetroot\Image_76.jpg
# D:/MPR Project/dataset/train\beetroot\Image_77.jpg
# D:/MPR Project/dataset/train\beetroot\Image_78.jpg
# D:/MPR Project/dataset/train\beetroot\Image_79.jpg
# D:/MPR Project/dataset/train\beetroot\Image_8.jpg
# D:/MPR Project/dataset/train\beetroot\Image_81.jpg
# D:/MPR Project/dataset/train\beetroot\Image_83.jpg
# D:/MPR Project/dataset/train\beetroot\Image_84.png
# D:/MPR Project/dataset/train\beetroot\Image_86.png
# D:/MPR Project/dataset/train\beetroot\Image_87.jpg
# D:/MPR Project/dataset/train\beetroot\Image_89.jpg
# D:/MPR Project/dataset/train\beetroot\Image_9.jpg
# D:/MPR Project/dataset/train\beetroot\Image_90.jpg
# D:/MPR Project/dataset/train\beetroot\Image_91.jpg
# D:/MPR Project/dataset/train\beetroot\Image_92.jpg
# D:/MPR Project/dataset/train\beetroot\Image_93.jpg
# D:/MPR Project/dataset/train\beetroot\Image_94.jpg
# D:/MPR Project/dataset/train\beetroot\Image_95.jpg
# D:/MPR Project/dataset/train\beetroot\Image_96.jpg
# D:/MPR Project/dataset/train\beetroot\Image_97.jpg
# D:/MPR Project/dataset/train\beetroot\Image_98.jpg
# D:/MPR Project/dataset/train\beetroot\Image_99.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_1.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_10.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_100.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_11.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_12.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_13.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_14.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_15.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_16.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_19.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_2.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_20.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_21.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_22.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_23.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_24.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_25.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_26.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_27.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_28.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_29.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_3.jpeg
# D:/MPR Project/dataset/train\bell pepper\Image_30.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_31.jpeg
# D:/MPR Project/dataset/train\bell pepper\Image_32.JPG
# D:/MPR Project/dataset/train\bell pepper\Image_33.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_34.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_35.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_36.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_37.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_38.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_39.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_4.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_40.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_41.png
# D:/MPR Project/dataset/train\bell pepper\Image_42.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_43.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_44.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_45.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_46.png
# D:/MPR Project/dataset/train\bell pepper\Image_47.png
# D:/MPR Project/dataset/train\bell pepper\Image_48.png
# D:/MPR Project/dataset/train\bell pepper\Image_49.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_5.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_50.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_51.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_52.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_53.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_54.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_55.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_56.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_57.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_6.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_60.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_61.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_62.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_63.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_64.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_65.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_66.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_67.png
# D:/MPR Project/dataset/train\bell pepper\Image_68.jpeg
# D:/MPR Project/dataset/train\bell pepper\Image_69.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_7.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_70.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_71.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_72.png
# D:/MPR Project/dataset/train\bell pepper\Image_73.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_74.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_75.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_76.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_77.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_78.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_79.JPG
# D:/MPR Project/dataset/train\bell pepper\Image_8.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_82.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_83.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_84.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_85.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_86.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_88.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_89.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_9.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_90.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_93.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_94.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_95.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_97.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_98.jpg
# D:/MPR Project/dataset/train\bell pepper\Image_99.jpeg
# D:/MPR Project/dataset/train\cabbage\Image_1.jpg
# D:/MPR Project/dataset/train\cabbage\Image_10.jpg
# D:/MPR Project/dataset/train\cabbage\Image_100.jpg
# D:/MPR Project/dataset/train\cabbage\Image_11.jpg
# D:/MPR Project/dataset/train\cabbage\Image_12.jpg
# D:/MPR Project/dataset/train\cabbage\Image_13.jpg
# D:/MPR Project/dataset/train\cabbage\Image_14.jpg
# D:/MPR Project/dataset/train\cabbage\Image_15.jpg
# D:/MPR Project/dataset/train\cabbage\Image_16.jpg
# D:/MPR Project/dataset/train\cabbage\Image_17.jpg
# D:/MPR Project/dataset/train\cabbage\Image_18.jpg
# D:/MPR Project/dataset/train\cabbage\Image_2.jpg
# D:/MPR Project/dataset/train\cabbage\Image_20.jpg
# D:/MPR Project/dataset/train\cabbage\Image_21.jpg
# D:/MPR Project/dataset/train\cabbage\Image_22.jpg
# D:/MPR Project/dataset/train\cabbage\Image_23.jpg
# D:/MPR Project/dataset/train\cabbage\Image_24.jpg
# D:/MPR Project/dataset/train\cabbage\Image_25.jpg
# D:/MPR Project/dataset/train\cabbage\Image_26.JPG
# D:/MPR Project/dataset/train\cabbage\Image_27.jpg
# D:/MPR Project/dataset/train\cabbage\Image_28.jpg
# D:/MPR Project/dataset/train\cabbage\Image_29.jpg
# D:/MPR Project/dataset/train\cabbage\Image_3.jpg
# D:/MPR Project/dataset/train\cabbage\Image_30.jpg
# D:/MPR Project/dataset/train\cabbage\Image_31.jpg
# D:/MPR Project/dataset/train\cabbage\Image_32.jpg
# D:/MPR Project/dataset/train\cabbage\Image_33.jpg
# D:/MPR Project/dataset/train\cabbage\Image_34.jpg
# D:/MPR Project/dataset/train\cabbage\Image_35.jpg
# D:/MPR Project/dataset/train\cabbage\Image_36.jpeg
# D:/MPR Project/dataset/train\cabbage\Image_37.jpg
# D:/MPR Project/dataset/train\cabbage\Image_38.jpg
# D:/MPR Project/dataset/train\cabbage\Image_39.jpg
# D:/MPR Project/dataset/train\cabbage\Image_4.jpg
# D:/MPR Project/dataset/train\cabbage\Image_42.jpg
# D:/MPR Project/dataset/train\cabbage\Image_43.jpg
# D:/MPR Project/dataset/train\cabbage\Image_44.jpg
# D:/MPR Project/dataset/train\cabbage\Image_45.jpg
# D:/MPR Project/dataset/train\cabbage\Image_46.jpg
# D:/MPR Project/dataset/train\cabbage\Image_47.JPG
# D:/MPR Project/dataset/train\cabbage\Image_48.jpg
# D:/MPR Project/dataset/train\cabbage\Image_49.JPG
# D:/MPR Project/dataset/train\cabbage\Image_5.jpg
# D:/MPR Project/dataset/train\cabbage\Image_50.jpg
# D:/MPR Project/dataset/train\cabbage\Image_51.jpg
# D:/MPR Project/dataset/train\cabbage\Image_52.jpg
# D:/MPR Project/dataset/train\cabbage\Image_53.jpg
# D:/MPR Project/dataset/train\cabbage\Image_54.jpg
# D:/MPR Project/dataset/train\cabbage\Image_55.jpg
# D:/MPR Project/dataset/train\cabbage\Image_56.jpg
# D:/MPR Project/dataset/train\cabbage\Image_57.jpg
# D:/MPR Project/dataset/train\cabbage\Image_58.jpg
# D:/MPR Project/dataset/train\cabbage\Image_59.jpg
# D:/MPR Project/dataset/train\cabbage\Image_6.jpg
# D:/MPR Project/dataset/train\cabbage\Image_60.JPG
# D:/MPR Project/dataset/train\cabbage\Image_61.jpg
# D:/MPR Project/dataset/train\cabbage\Image_63.png
# D:/MPR Project/dataset/train\cabbage\Image_65.jpg
# D:/MPR Project/dataset/train\cabbage\Image_66.jpg
# D:/MPR Project/dataset/train\cabbage\Image_67.jpg
# D:/MPR Project/dataset/train\cabbage\Image_68.jpg
# D:/MPR Project/dataset/train\cabbage\Image_69.JPG
# D:/MPR Project/dataset/train\cabbage\Image_7.jpg
# D:/MPR Project/dataset/train\cabbage\Image_70.jpg
# D:/MPR Project/dataset/train\cabbage\Image_71.jpg
# D:/MPR Project/dataset/train\cabbage\Image_72.jpg
# D:/MPR Project/dataset/train\cabbage\Image_73.jpg
# D:/MPR Project/dataset/train\cabbage\Image_74.jpg
# D:/MPR Project/dataset/train\cabbage\Image_75.jpg
# D:/MPR Project/dataset/train\cabbage\Image_76.jpg
# D:/MPR Project/dataset/train\cabbage\Image_77.jpg
# D:/MPR Project/dataset/train\cabbage\Image_78.jpg
# D:/MPR Project/dataset/train\cabbage\Image_79.jpg
# D:/MPR Project/dataset/train\cabbage\Image_8.jpg
# D:/MPR Project/dataset/train\cabbage\Image_80.jpg
# D:/MPR Project/dataset/train\cabbage\Image_81.jpg
# D:/MPR Project/dataset/train\cabbage\Image_85.jpg
# D:/MPR Project/dataset/train\cabbage\Image_86.jpeg
# D:/MPR Project/dataset/train\cabbage\Image_87.jpg
# D:/MPR Project/dataset/train\cabbage\Image_88.jpg
# D:/MPR Project/dataset/train\cabbage\Image_89.jpg
# D:/MPR Project/dataset/train\cabbage\Image_9.jpg
# D:/MPR Project/dataset/train\cabbage\Image_90.jpg
# D:/MPR Project/dataset/train\cabbage\Image_91.jpg
# D:/MPR Project/dataset/train\cabbage\Image_92.jpg
# D:/MPR Project/dataset/train\cabbage\Image_93.jpg
# D:/MPR Project/dataset/train\cabbage\Image_94.jpg
# D:/MPR Project/dataset/train\cabbage\Image_95.jpg
# D:/MPR Project/dataset/train\cabbage\Image_96.jpg
# D:/MPR Project/dataset/train\cabbage\Image_97.jpg
# D:/MPR Project/dataset/train\cabbage\Image_98.jpg
# D:/MPR Project/dataset/train\cabbage\Image_99.jpg
# D:/MPR Project/dataset/train\capsicum\Image_1.jpg
# D:/MPR Project/dataset/train\capsicum\Image_10.jpg
# D:/MPR Project/dataset/train\capsicum\Image_100.JPG
# D:/MPR Project/dataset/train\capsicum\Image_11.JPG
# D:/MPR Project/dataset/train\capsicum\Image_12.jpg
# D:/MPR Project/dataset/train\capsicum\Image_13.jpg
# D:/MPR Project/dataset/train\capsicum\Image_14.jpg
# D:/MPR Project/dataset/train\capsicum\Image_15.jpg
# D:/MPR Project/dataset/train\capsicum\Image_16.jpg
# D:/MPR Project/dataset/train\capsicum\Image_17.jpg
# D:/MPR Project/dataset/train\capsicum\Image_18.jpg
# D:/MPR Project/dataset/train\capsicum\Image_19.jpg
# D:/MPR Project/dataset/train\capsicum\Image_2.jpg
# D:/MPR Project/dataset/train\capsicum\Image_20.jpg
# D:/MPR Project/dataset/train\capsicum\Image_21.jpg
# D:/MPR Project/dataset/train\capsicum\Image_22.jpg
# D:/MPR Project/dataset/train\capsicum\Image_23.jpg
# D:/MPR Project/dataset/train\capsicum\Image_24.jpg
# D:/MPR Project/dataset/train\capsicum\Image_25.jpg
# D:/MPR Project/dataset/train\capsicum\Image_26.jpg
# D:/MPR Project/dataset/train\capsicum\Image_27.jpg
# D:/MPR Project/dataset/train\capsicum\Image_28.jpg
# D:/MPR Project/dataset/train\capsicum\Image_29.jpg
# D:/MPR Project/dataset/train\capsicum\Image_3.JPG
# D:/MPR Project/dataset/train\capsicum\Image_30.jpg
# D:/MPR Project/dataset/train\capsicum\Image_31.jpg
# D:/MPR Project/dataset/train\capsicum\Image_32.jpg
# D:/MPR Project/dataset/train\capsicum\Image_33.jpg
# D:/MPR Project/dataset/train\capsicum\Image_34.jpg
# D:/MPR Project/dataset/train\capsicum\Image_35.jpg
# D:/MPR Project/dataset/train\capsicum\Image_36.jpg
# D:/MPR Project/dataset/train\capsicum\Image_37.jpg
# D:/MPR Project/dataset/train\capsicum\Image_38.jpg
# D:/MPR Project/dataset/train\capsicum\Image_39.jpg
# D:/MPR Project/dataset/train\capsicum\Image_4.jpg
# D:/MPR Project/dataset/train\capsicum\Image_40.jpg
# D:/MPR Project/dataset/train\capsicum\Image_41.jpg
# D:/MPR Project/dataset/train\capsicum\Image_42.jpg
# D:/MPR Project/dataset/train\capsicum\Image_43.jpg
# D:/MPR Project/dataset/train\capsicum\Image_45.jpg
# D:/MPR Project/dataset/train\capsicum\Image_46.jpg
# D:/MPR Project/dataset/train\capsicum\Image_47.jpg
# D:/MPR Project/dataset/train\capsicum\Image_48.jpg
# D:/MPR Project/dataset/train\capsicum\Image_49.png
# D:/MPR Project/dataset/train\capsicum\Image_5.jpg
# D:/MPR Project/dataset/train\capsicum\Image_50.jpg
# D:/MPR Project/dataset/train\capsicum\Image_51.jpg
# D:/MPR Project/dataset/train\capsicum\Image_53.jpg
# D:/MPR Project/dataset/train\capsicum\Image_54.jpg
# D:/MPR Project/dataset/train\capsicum\Image_55.jpg
# D:/MPR Project/dataset/train\capsicum\Image_56.jpg
# D:/MPR Project/dataset/train\capsicum\Image_6.jpg
# D:/MPR Project/dataset/train\capsicum\Image_60.jpg
# D:/MPR Project/dataset/train\capsicum\Image_62.jpg
# D:/MPR Project/dataset/train\capsicum\Image_64.jpg
# D:/MPR Project/dataset/train\capsicum\Image_65.jpg
# D:/MPR Project/dataset/train\capsicum\Image_66.jpg
# D:/MPR Project/dataset/train\capsicum\Image_67.jpg
# D:/MPR Project/dataset/train\capsicum\Image_68.jpg
# D:/MPR Project/dataset/train\capsicum\Image_69.jpg
# D:/MPR Project/dataset/train\capsicum\Image_7.jpg
# D:/MPR Project/dataset/train\capsicum\Image_70.jpg
# D:/MPR Project/dataset/train\capsicum\Image_71.jpeg
# D:/MPR Project/dataset/train\capsicum\Image_73.jpg
# D:/MPR Project/dataset/train\capsicum\Image_74.jpg
# D:/MPR Project/dataset/train\capsicum\Image_75.jpg
# D:/MPR Project/dataset/train\capsicum\Image_76.jpg
# D:/MPR Project/dataset/train\capsicum\Image_78.jpg
# D:/MPR Project/dataset/train\capsicum\Image_79.JPG
# D:/MPR Project/dataset/train\capsicum\Image_8.jpg
# D:/MPR Project/dataset/train\capsicum\Image_80.jpg
# D:/MPR Project/dataset/train\capsicum\Image_81.jpg
# D:/MPR Project/dataset/train\capsicum\Image_82.jpg
# D:/MPR Project/dataset/train\capsicum\Image_83.jpg
# D:/MPR Project/dataset/train\capsicum\Image_84.jpg
# D:/MPR Project/dataset/train\capsicum\Image_85.jpg
# D:/MPR Project/dataset/train\capsicum\Image_86.jpg
# D:/MPR Project/dataset/train\capsicum\Image_87.jpg
# D:/MPR Project/dataset/train\capsicum\Image_88.jpeg
# D:/MPR Project/dataset/train\capsicum\Image_89.jpg
# D:/MPR Project/dataset/train\capsicum\Image_9.jpg
# D:/MPR Project/dataset/train\capsicum\Image_90.jpg
# D:/MPR Project/dataset/train\capsicum\Image_92.jpg
# D:/MPR Project/dataset/train\capsicum\Image_93.jpg
# D:/MPR Project/dataset/train\capsicum\Image_95.png
# D:/MPR Project/dataset/train\capsicum\Image_96.JPG
# D:/MPR Project/dataset/train\capsicum\Image_97.jpg
# D:/MPR Project/dataset/train\capsicum\Image_98.jpg
# D:/MPR Project/dataset/train\capsicum\Image_99.jpg
# D:/MPR Project/dataset/train\carrot\Image_1.jpg
# D:/MPR Project/dataset/train\carrot\Image_10.jpeg
# D:/MPR Project/dataset/train\carrot\Image_100.jpg
# D:/MPR Project/dataset/train\carrot\Image_11.jpg
# D:/MPR Project/dataset/train\carrot\Image_12.jpg
# D:/MPR Project/dataset/train\carrot\Image_13.jpg
# D:/MPR Project/dataset/train\carrot\Image_14.jpeg
# D:/MPR Project/dataset/train\carrot\Image_15.jpg
# D:/MPR Project/dataset/train\carrot\Image_17.jpeg
# D:/MPR Project/dataset/train\carrot\Image_2.jpg
# D:/MPR Project/dataset/train\carrot\Image_20.jpg
# D:/MPR Project/dataset/train\carrot\Image_23.jpg
# D:/MPR Project/dataset/train\carrot\Image_24.jpg
# D:/MPR Project/dataset/train\carrot\Image_25.jpg
# D:/MPR Project/dataset/train\carrot\Image_26.jpg
# D:/MPR Project/dataset/train\carrot\Image_27.jpg
# D:/MPR Project/dataset/train\carrot\Image_28.jpg
# D:/MPR Project/dataset/train\carrot\Image_29.jpg
# D:/MPR Project/dataset/train\carrot\Image_3.jpg
# D:/MPR Project/dataset/train\carrot\Image_31.jpg
# D:/MPR Project/dataset/train\carrot\Image_32.jpg
# D:/MPR Project/dataset/train\carrot\Image_34.jpg
# D:/MPR Project/dataset/train\carrot\Image_35.jpg
# D:/MPR Project/dataset/train\carrot\Image_36.jpg
# D:/MPR Project/dataset/train\carrot\Image_37.jpg
# D:/MPR Project/dataset/train\carrot\Image_40.jpg
# D:/MPR Project/dataset/train\carrot\Image_41.jpg
# D:/MPR Project/dataset/train\carrot\Image_42.jpg
# D:/MPR Project/dataset/train\carrot\Image_44.png
# D:/MPR Project/dataset/train\carrot\Image_46.jpg
# D:/MPR Project/dataset/train\carrot\Image_47.jpg
# D:/MPR Project/dataset/train\carrot\Image_49.jpg
# D:/MPR Project/dataset/train\carrot\Image_5.jpg
# D:/MPR Project/dataset/train\carrot\Image_50.jpg
# D:/MPR Project/dataset/train\carrot\Image_51.jpg
# D:/MPR Project/dataset/train\carrot\Image_52.jpg
# D:/MPR Project/dataset/train\carrot\Image_53.jpg
# D:/MPR Project/dataset/train\carrot\Image_54.jpg
# D:/MPR Project/dataset/train\carrot\Image_55.jpg
# D:/MPR Project/dataset/train\carrot\Image_56.jpg
# D:/MPR Project/dataset/train\carrot\Image_57.jpg
# D:/MPR Project/dataset/train\carrot\Image_58.jpg
# D:/MPR Project/dataset/train\carrot\Image_59.jpg
# D:/MPR Project/dataset/train\carrot\Image_6.jpg
# D:/MPR Project/dataset/train\carrot\Image_60.jpg
# D:/MPR Project/dataset/train\carrot\Image_61.jpg
# D:/MPR Project/dataset/train\carrot\Image_62.png
# D:/MPR Project/dataset/train\carrot\Image_63.jpg
# D:/MPR Project/dataset/train\carrot\Image_64.jpg
# D:/MPR Project/dataset/train\carrot\Image_65.jpg
# D:/MPR Project/dataset/train\carrot\Image_66.jpg
# D:/MPR Project/dataset/train\carrot\Image_67.jpg
# D:/MPR Project/dataset/train\carrot\Image_68.png
# D:/MPR Project/dataset/train\carrot\Image_69.jpg
# D:/MPR Project/dataset/train\carrot\Image_7.jpg
# D:/MPR Project/dataset/train\carrot\Image_70.jpg
# D:/MPR Project/dataset/train\carrot\Image_71.jpg
# D:/MPR Project/dataset/train\carrot\Image_72.jpg
# D:/MPR Project/dataset/train\carrot\Image_73.jpeg
# D:/MPR Project/dataset/train\carrot\Image_75.jpg
# D:/MPR Project/dataset/train\carrot\Image_76.jpg
# D:/MPR Project/dataset/train\carrot\Image_77.jpg
# D:/MPR Project/dataset/train\carrot\Image_78.jpg
# D:/MPR Project/dataset/train\carrot\Image_79.jpg
# D:/MPR Project/dataset/train\carrot\Image_8.JPG
# D:/MPR Project/dataset/train\carrot\Image_80.png
# D:/MPR Project/dataset/train\carrot\Image_81.jpg
# D:/MPR Project/dataset/train\carrot\Image_82.jpg
# D:/MPR Project/dataset/train\carrot\Image_83.jpg
# D:/MPR Project/dataset/train\carrot\Image_84.jpg
# D:/MPR Project/dataset/train\carrot\Image_85.jpg
# D:/MPR Project/dataset/train\carrot\Image_86.jpg
# D:/MPR Project/dataset/train\carrot\Image_88.jpg
# D:/MPR Project/dataset/train\carrot\Image_89.jpg
# D:/MPR Project/dataset/train\carrot\Image_9.jpg
# D:/MPR Project/dataset/train\carrot\Image_90.jpg
# D:/MPR Project/dataset/train\carrot\Image_91.jpg
# D:/MPR Project/dataset/train\carrot\Image_93.jpg
# D:/MPR Project/dataset/train\carrot\Image_94.jpg
# D:/MPR Project/dataset/train\carrot\Image_96.jpg
# D:/MPR Project/dataset/train\carrot\Image_98.jpg
# D:/MPR Project/dataset/train\carrot\Image_99.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_1.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_10.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_100.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_11.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_12.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_13.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_14.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_15.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_16.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_17.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_18.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_19.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_2.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_20.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_21.png
# D:/MPR Project/dataset/train\cauliflower\Image_22.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_23.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_24.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_25.JPG
# D:/MPR Project/dataset/train\cauliflower\Image_26.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_27.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_28.jpg
# D:/MPR Project/dataset/train\cauliflower\Image_29.jpg
# ...
# D:/MPR Project/dataset/validation\capsicum\Image_8.jpg
# D:/MPR Project/dataset/validation\capsicum\Image_9.jpg
# D:/MPR Project/dataset/validation\carrot\Image_1.jpg
# D:/MPR Project/dataset/validation\carrot\Image_10.jpg
# D:/MPR Project/dataset/validation\carrot\Image_2.jpg
# D:/MPR Project/dataset/validation\carrot\Image_3.jpg
# D:/MPR Project/dataset/validation\carrot\Image_4.png
# D:/MPR Project/dataset/validation\carrot\Image_5.jpg
# D:/MPR Project/dataset/validation\carrot\Image_6.jpg
# D:/MPR Project/dataset/validation\carrot\Image_7.JPG
# D:/MPR Project/dataset/validation\carrot\Image_8.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_1.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_10.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_2.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_3.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_4.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_5.JPG
# D:/MPR Project/dataset/validation\cauliflower\Image_6.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_7.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_8.jpg
# D:/MPR Project/dataset/validation\cauliflower\Image_9.jpg
# D:/MPR Project/dataset/validation\chilli pepper\Image_1.jpg
# D:/MPR Project/dataset/validation\chilli pepper\Image_10.jpg
# D:/MPR Project/dataset/validation\chilli pepper\Image_2.png
# D:/MPR Project/dataset/validation\chilli pepper\Image_3.jpg
# D:/MPR Project/dataset/validation\chilli pepper\Image_4.jpg
# D:/MPR Project/dataset/validation\chilli pepper\Image_5.png
# D:/MPR Project/dataset/validation\chilli pepper\Image_7.jpg
# D:/MPR Project/dataset/validation\chilli pepper\Image_8.jpg
# D:/MPR Project/dataset/validation\chilli pepper\Image_9.jpg
# D:/MPR Project/dataset/validation\corn\Image_1.jpg
# D:/MPR Project/dataset/validation\corn\Image_10.jpg
# D:/MPR Project/dataset/validation\corn\Image_2.jpg
# D:/MPR Project/dataset/validation\corn\Image_3.jpg
# D:/MPR Project/dataset/validation\corn\Image_4.jpg
# D:/MPR Project/dataset/validation\corn\Image_5.jpg
# D:/MPR Project/dataset/validation\corn\Image_6.jpg
# D:/MPR Project/dataset/validation\corn\Image_7.jpg
# D:/MPR Project/dataset/validation\corn\Image_8.jpg
# D:/MPR Project/dataset/validation\corn\Image_9.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_1.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_10.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_2.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_3.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_4.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_5.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_6.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_7.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_8.jpg
# D:/MPR Project/dataset/validation\cucumber\Image_9.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_1.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_10.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_2.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_3.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_4.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_5.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_6.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_7.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_8.jpg
# D:/MPR Project/dataset/validation\eggplant\Image_9.jpg
# D:/MPR Project/dataset/validation\garlic\Image_1.jpg
# D:/MPR Project/dataset/validation\garlic\Image_10.jpg
# D:/MPR Project/dataset/validation\garlic\Image_2.jpg
# D:/MPR Project/dataset/validation\garlic\Image_3.jpg
# D:/MPR Project/dataset/validation\garlic\Image_4.jpg
# D:/MPR Project/dataset/validation\garlic\Image_5.jpg
# D:/MPR Project/dataset/validation\garlic\Image_6.jpg
# D:/MPR Project/dataset/validation\garlic\Image_7.jpg
# D:/MPR Project/dataset/validation\garlic\Image_8.jpg
# D:/MPR Project/dataset/validation\garlic\Image_9.jpg
# D:/MPR Project/dataset/validation\ginger\Image_1.jpg
# D:/MPR Project/dataset/validation\ginger\Image_10.jpg
# D:/MPR Project/dataset/validation\ginger\Image_2.jpg
# D:/MPR Project/dataset/validation\ginger\Image_3.jpg
# D:/MPR Project/dataset/validation\ginger\Image_4.jpg
# D:/MPR Project/dataset/validation\ginger\Image_5.jpg
# D:/MPR Project/dataset/validation\ginger\Image_6.jpg
# D:/MPR Project/dataset/validation\ginger\Image_7.jpg
# D:/MPR Project/dataset/validation\ginger\Image_8.jpg
# D:/MPR Project/dataset/validation\ginger\Image_9.jpg
# D:/MPR Project/dataset/validation\grapes\Image_1.jpg
# D:/MPR Project/dataset/validation\grapes\Image_10.jpg
# D:/MPR Project/dataset/validation\grapes\Image_2.jpg
# D:/MPR Project/dataset/validation\grapes\Image_3.jpg
# D:/MPR Project/dataset/validation\grapes\Image_4.jpg
# D:/MPR Project/dataset/validation\grapes\Image_6.jpg
# D:/MPR Project/dataset/validation\grapes\Image_7.JPG
# D:/MPR Project/dataset/validation\grapes\Image_8.jpg
# D:/MPR Project/dataset/validation\grapes\Image_9.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_10.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_2.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_3.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_4.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_5.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_6.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_7.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_8.jpg
# D:/MPR Project/dataset/validation\jalepeno\Image_9.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_1.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_10.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_2.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_3.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_4.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_5.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_6.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_7.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_8.jpg
# D:/MPR Project/dataset/validation\kiwi\Image_9.jpg
# D:/MPR Project/dataset/validation\lemon\Image_1.png
# D:/MPR Project/dataset/validation\lemon\Image_10.jpg
# D:/MPR Project/dataset/validation\lemon\Image_2.jpg
# D:/MPR Project/dataset/validation\lemon\Image_3.jpg
# D:/MPR Project/dataset/validation\lemon\Image_4.jpg
# D:/MPR Project/dataset/validation\lemon\Image_5.jpg
# D:/MPR Project/dataset/validation\lemon\Image_6.png
# D:/MPR Project/dataset/validation\lemon\Image_7.jpg
# D:/MPR Project/dataset/validation\lemon\Image_8.jpg
# D:/MPR Project/dataset/validation\lemon\Image_9.png
# D:/MPR Project/dataset/validation\lettuce\Image_1.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_10.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_2.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_3.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_4.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_6.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_7.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_8.jpg
# D:/MPR Project/dataset/validation\lettuce\Image_9.jpg
# D:/MPR Project/dataset/validation\mango\Image_1.jpg
# D:/MPR Project/dataset/validation\mango\Image_10.jpg
# D:/MPR Project/dataset/validation\mango\Image_2.jpg
# D:/MPR Project/dataset/validation\mango\Image_3.jpg
# D:/MPR Project/dataset/validation\mango\Image_4.jpg
# D:/MPR Project/dataset/validation\mango\Image_5.jpg
# D:/MPR Project/dataset/validation\mango\Image_6.jpg
# D:/MPR Project/dataset/validation\mango\Image_7.jpg
# D:/MPR Project/dataset/validation\mango\Image_8.jpg
# D:/MPR Project/dataset/validation\mango\Image_9.jpg
# D:/MPR Project/dataset/validation\onion\Image_1.jpg
# D:/MPR Project/dataset/validation\onion\Image_10.jpg
# D:/MPR Project/dataset/validation\onion\Image_2.jpg
# D:/MPR Project/dataset/validation\onion\Image_3.jpg
# D:/MPR Project/dataset/validation\onion\Image_4.jpg
# D:/MPR Project/dataset/validation\onion\Image_5.jpg
# D:/MPR Project/dataset/validation\onion\Image_6.jpg
# D:/MPR Project/dataset/validation\onion\Image_7.png
# D:/MPR Project/dataset/validation\onion\Image_8.jpg
# D:/MPR Project/dataset/validation\onion\Image_9.jpg
# D:/MPR Project/dataset/validation\orange\Image_1.png
# D:/MPR Project/dataset/validation\orange\Image_10.png
# D:/MPR Project/dataset/validation\orange\Image_2.jpg
# D:/MPR Project/dataset/validation\orange\Image_3.jpg
# D:/MPR Project/dataset/validation\orange\Image_4.jpg
# D:/MPR Project/dataset/validation\orange\Image_5.jpg
# D:/MPR Project/dataset/validation\orange\Image_6.jpg
# D:/MPR Project/dataset/validation\orange\Image_7.jpg
# D:/MPR Project/dataset/validation\orange\Image_9.jpg
# D:/MPR Project/dataset/validation\paprika\Image_1.jpg
# D:/MPR Project/dataset/validation\paprika\Image_10.jpg
# D:/MPR Project/dataset/validation\paprika\Image_2.jpg
# D:/MPR Project/dataset/validation\paprika\Image_3.jpg
# D:/MPR Project/dataset/validation\paprika\Image_4.jpg
# D:/MPR Project/dataset/validation\paprika\Image_5.jpg
# D:/MPR Project/dataset/validation\paprika\Image_6.jpg
# D:/MPR Project/dataset/validation\paprika\Image_7.jpg
# D:/MPR Project/dataset/validation\paprika\Image_8.jpg
# D:/MPR Project/dataset/validation\paprika\Image_9.jpg
# D:/MPR Project/dataset/validation\pear\Image_1.jpg
# D:/MPR Project/dataset/validation\pear\Image_10.jpg
# D:/MPR Project/dataset/validation\pear\Image_2.jpg
# D:/MPR Project/dataset/validation\pear\Image_3.jpg
# D:/MPR Project/dataset/validation\pear\Image_4.jpg
# D:/MPR Project/dataset/validation\pear\Image_5.jpg
# D:/MPR Project/dataset/validation\pear\Image_6.jpg
# D:/MPR Project/dataset/validation\pear\Image_7.jpg
# D:/MPR Project/dataset/validation\pear\Image_8.jpg
# D:/MPR Project/dataset/validation\pear\Image_9.jpg
# D:/MPR Project/dataset/validation\peas\Image_1.jpg
# D:/MPR Project/dataset/validation\peas\Image_10.jpg
# D:/MPR Project/dataset/validation\peas\Image_2.jpg
# D:/MPR Project/dataset/validation\peas\Image_3.jpg
# D:/MPR Project/dataset/validation\peas\Image_4.jpg
# D:/MPR Project/dataset/validation\peas\Image_5.jpg
# D:/MPR Project/dataset/validation\peas\Image_6.png
# D:/MPR Project/dataset/validation\peas\Image_7.jpg
# D:/MPR Project/dataset/validation\peas\Image_8.jpg
# D:/MPR Project/dataset/validation\peas\Image_9.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_1.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_10.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_2.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_3.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_4.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_5.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_6.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_7.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_8.jpg
# D:/MPR Project/dataset/validation\pineapple\Image_9.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_1.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_10.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_2.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_3.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_4.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_5.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_6.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_7.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_8.jpg
# D:/MPR Project/dataset/validation\pomegranate\Image_9.jpg
# D:/MPR Project/dataset/validation\potato\Image_1.jpg
# D:/MPR Project/dataset/validation\potato\Image_10.jpg
# D:/MPR Project/dataset/validation\potato\Image_2.jpg
# D:/MPR Project/dataset/validation\potato\Image_3.jpg
# D:/MPR Project/dataset/validation\potato\Image_4.jpg
# D:/MPR Project/dataset/validation\potato\Image_5.JPG
# D:/MPR Project/dataset/validation\potato\Image_6.jpg
# D:/MPR Project/dataset/validation\potato\Image_7.jpg
# D:/MPR Project/dataset/validation\potato\Image_8.jpg
# D:/MPR Project/dataset/validation\potato\Image_9.jpg
# D:/MPR Project/dataset/validation\raddish\Image_1.jpg
# D:/MPR Project/dataset/validation\raddish\Image_10.jpg
# D:/MPR Project/dataset/validation\raddish\Image_2.jpg
# D:/MPR Project/dataset/validation\raddish\Image_3.jpg
# D:/MPR Project/dataset/validation\raddish\Image_4.jpg
# D:/MPR Project/dataset/validation\raddish\Image_5.png
# D:/MPR Project/dataset/validation\raddish\Image_6.jpg
# D:/MPR Project/dataset/validation\raddish\Image_7.jpg
# D:/MPR Project/dataset/validation\raddish\Image_8.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_1.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_10.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_2.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_3.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_4.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_5.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_6.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_7.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_8.jpg
# D:/MPR Project/dataset/validation\soy beans\Image_9.jpg
# D:/MPR Project/dataset/validation\spinach\Image_1.jpg
# D:/MPR Project/dataset/validation\spinach\Image_10.jpg
# D:/MPR Project/dataset/validation\spinach\Image_2.jpg
# D:/MPR Project/dataset/validation\spinach\Image_3.jpg
# D:/MPR Project/dataset/validation\spinach\Image_4.jpg
# D:/MPR Project/dataset/validation\spinach\Image_5.jpg
# D:/MPR Project/dataset/validation\spinach\Image_6.jpg
# D:/MPR Project/dataset/validation\spinach\Image_7.jpg
# D:/MPR Project/dataset/validation\spinach\Image_8.jpg
# D:/MPR Project/dataset/validation\spinach\Image_9.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_1.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_10.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_2.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_3.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_4.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_5.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_6.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_7.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_8.jpg
# D:/MPR Project/dataset/validation\sweetcorn\Image_9.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_1.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_10.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_2.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_3.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_4.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_5.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_6.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_7.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_8.jpg
# D:/MPR Project/dataset/validation\sweetpotato\Image_9.jpg
# D:/MPR Project/dataset/validation\tomato\Image_1.jpg
# D:/MPR Project/dataset/validation\tomato\Image_10.jpg
# D:/MPR Project/dataset/validation\tomato\Image_2.jpg
# D:/MPR Project/dataset/validation\tomato\Image_3.jpg
# D:/MPR Project/dataset/validation\tomato\Image_4.jpg
# D:/MPR Project/dataset/validation\tomato\Image_5.jpg
# D:/MPR Project/dataset/validation\tomato\Image_6.jpg
# D:/MPR Project/dataset/validation\tomato\Image_7.jpg
# D:/MPR Project/dataset/validation\tomato\Image_8.jpg
# D:/MPR Project/dataset/validation\tomato\Image_9.jpg
# D:/MPR Project/dataset/validation\turnip\Image_1.jpg
# D:/MPR Project/dataset/validation\turnip\Image_10.jpg
# D:/MPR Project/dataset/validation\turnip\Image_2.jpg
# D:/MPR Project/dataset/validation\turnip\Image_3.jpg
# D:/MPR Project/dataset/validation\turnip\Image_4.jpg
# D:/MPR Project/dataset/validation\turnip\Image_5.jpg
# D:/MPR Project/dataset/validation\turnip\Image_6.jpg
# D:/MPR Project/dataset/validation\turnip\Image_7.jpg
# D:/MPR Project/dataset/validation\turnip\Image_8.jpg
# D:/MPR Project/dataset/validation\turnip\Image_9.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_1.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_10.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_2.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_3.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_4.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_5.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_6.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_7.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_8.jpg
# D:/MPR Project/dataset/validation\watermelon\Image_9.jpg

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img,img_to_array
print(tf.__version__)
# Out:
# 2.17.0

# %%
train_dir = Path('D:/MPR Project/dataset/train')
train_filepaths = list(train_dir.glob(r'**/*.jpg'))
#print(train_filepaths)

# %%
test_dir = Path('D:/MPR Project/dataset')
test_filepaths = list(test_dir.glob(r'**/*.jpg'))
#print(test_filepaths)

# %%
val_dir = Path('D:/MPR Project/dataset/validation')
val_filepaths = list(test_dir.glob(r'**/*.jpg'))

# %%
def image_processing(filepath):
    """ Create a DataFrame with the filepath and the labels of the pictures
    """
    global labels
    labels = [str(filepath[i]).split("\\")[-2] for i in range(len(filepath))]

    filepath = pd.Series(filepath, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    # Concatenate filepaths and labels
    df = pd.concat([filepath, labels], axis=1)

    # Shuffle the DataFrame and reset index
    df = df.sample(frac=1).reset_index(drop = True)
    
    return df

# %%
train_df = image_processing(train_filepaths)
test_df = image_processing(test_filepaths)
val_df = image_processing(val_filepaths)

# %%
print('-- Training set --\n')
print(f'Number of pictures: {train_df.shape[0]}\n')
print(f'Number of different labels: {len(train_df.Label.unique())}\n')
print(f'Labels: {train_df.Label.unique()}')
# Out:
# -- Training set --
#
# Number of pictures: 2855
#
# Number of different labels: 36
#
# Labels: ['sweetpotato' 'potato' 'pineapple' 'eggplant' 'paprika' 'spinach'
#  'capsicum' 'onion' 'corn' 'grapes' 'watermelon' 'lettuce' 'sweetcorn'
#  'raddish' 'peas' 'bell pepper' 'chilli pepper' 'cabbage' 'soy beans'
#  'ginger' 'lemon' 'tomato' 'mango' 'jalepeno' 'orange' 'beetroot' 'carrot'
#  'garlic' 'banana' 'turnip' 'pomegranate' 'kiwi' 'apple' 'cucumber' 'pear'
#  'cauliflower']

# %%
train_df.head(5)
# Out:
#                                             Filepath        Label
# 0  D:\MPR Project\dataset\train\sweetpotato\Image...  sweetpotato
# 1   D:\MPR Project\dataset\train\potato\Image_29.jpg       potato
# 2  D:\MPR Project\dataset\train\pineapple\Image_3...    pineapple
# 3  D:\MPR Project\dataset\train\eggplant\Image_19...     eggplant
# 4  D:\MPR Project\dataset\train\paprika\Image_74.jpg      paprika

# %%
df_unique = train_df.copy().drop_duplicates(subset=["Label"]).reset_index()

# Display some pictures of the dataset
fig, axes = plt.subplots(nrows=6, ncols=6, figsize=(8, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(df_unique.Filepath[i]))
    ax.set_title(df_unique.Label[i], fontsize = 12)
plt.tight_layout(pad=0.5)
plt.show()

# %%
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
)

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 2855 validated image filenames belonging to 36 classes.

# %%
val_images = train_generator.flow_from_dataframe(
    dataframe=val_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=0,
    rotation_range=30,
    zoom_range=0.15,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    horizontal_flip=True,
    fill_mode="nearest"
)
# Out:
# Found 3535 validated image filenames belonging to 36 classes.

# %%
test_images = test_generator.flow_from_dataframe(
    dataframe=test_df,
    x_col='Filepath',
    y_col='Label',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3535 validated image filenames belonging to 36 classes.

# %%
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)
pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(36, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=10,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# c:\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 766s 8s/step - accuracy: 0.3445 - loss: 2.5137 - val_accuracy: 0.7836 - val_loss: 0.6804
# Epoch 2/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 717s 8s/step - accuracy: 0.7900 - loss: 0.6229 - val_accuracy: 0.8984 - val_loss: 0.3453
# Epoch 3/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 724s 8s/step - accuracy: 0.8843 - loss: 0.3448 - val_accuracy: 0.9347 - val_loss: 0.2283
# Epoch 4/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 711s 8s/step - accuracy: 0.9339 - loss: 0.2195 - val_accuracy: 0.9635 - val_loss: 0.1495
# Epoch 5/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 728s 8s/step - accuracy: 0.9611 - loss: 0.1372 - val_accuracy: 0.9717 - val_loss: 0.1098
# Epoch 6/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 763s 8s/step - accuracy: 0.9656 - loss: 0.1132 - val_accuracy: 0.9813 - val_loss: 0.0907
# Epoch 7/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 718s 8s/step - accuracy: 0.9770 - loss: 0.0827 - val_accuracy: 0.9842 - val_loss: 0.0783
# Epoch 8/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 709s 8s/step - accuracy: 0.9851 - loss: 0.0599 - val_accuracy: 0.9864 - val_loss: 0.0619
# Epoch 9/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 593s 6s/step - accuracy: 0.9886 - loss: 0.0493 - val_accuracy: 0.9672 - val_loss: 0.1012
# Epoch 10/10
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 463s 5s/step - accuracy: 0.9819 - loss: 0.0587 - val_accuracy: 0.9895 - val_loss: 0.0478

# %%
def output(location):
    img=load_img(location,target_size=(224,224,3))
    img=img_to_array(img)
    img=img/255
    img=np.expand_dims(img,[0])
    answer=model.predict(img)
    y_class = answer.argmax(axis=-1)
    y = " ".join(str(x) for x in y_class)
    y = int(y)
    res = labels[y]
    return res

# %%
print(output("D:/Downloads/Peas_in_pods_-_Studio.jpg"))
#banana
print(output("D:/MPR Project/dataset/test/carrot/Image_1.jpg"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# beetroot
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# apple

# %%
model.save('FV.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
